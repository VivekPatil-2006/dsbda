# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Website URL
url = "https://books.toscrape.com/"

# Send request
response = requests.get(url)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Find all books
books = soup.find_all("article", class_="product_pod")

# Empty list
data = []

# Loop through books
for book in books:

    # Book Name
    book_name = book.h3.a["title"]

    # Rating
    rating = book.p["class"][1]

    # Price
    price = book.find("p", class_="price_color").text

    # Comment / Tag
    comment = "Book Review Available"

    # Customer Name (Demo)
    customer_name = "Book Customer"

    # Store data
    data.append([
        customer_name,
        book_name,
        rating,
        comment,
        price
    ])

# Create DataFrame
df = pd.DataFrame(
    data,
    columns=[
        "Customer Name",
        "Book Name",
        "Rating",
        "Comment Tag",
        "Price"
    ]
)

# Show data
print(df)

# Save to CSV
df.to_csv("book_reviews.csv", index=False)

print("Data saved to book_reviews.csv")
# Out:
#     Customer Name                                          Book Name Rating  \
# 0   Book Customer                               A Light in the Attic  Three
# 1   Book Customer                                 Tipping the Velvet    One
# 2   Book Customer                                         Soumission    One
# 3   Book Customer                                      Sharp Objects   Four
# 4   Book Customer              Sapiens: A Brief History of Humankind   Five
# 5   Book Customer                                    The Requiem Red    One
# 6   Book Customer  The Dirty Little Secrets of Getting Your Dream...   Four
# 7   Book Customer  The Coming Woman: A Novel Based on the Life of...  Three
# 8   Book Customer  The Boys in the Boat: Nine Americans and Their...   Four
# 9   Book Customer                                    The Black Maria    One
# 10  Book Customer     Starving Hearts (Triangular Trade Trilogy, #1)    Two
# 11  Book Customer                              Shakespeare's Sonnets   Four
# 12  Book Customer                                        Set Me Free   Five
# 13  Book Customer  Scott Pilgrim's Precious Little Life (Scott Pi...   Five
# 14  Book Customer                          Rip it Up and Start Again   Five
# 15  Book Customer  Our Band Could Be Your Life: Scenes from the A...  Three
# 16  Book Customer                                               Olio    One
# 17  Book Customer  Mesaerion: The Best Science Fiction Stories 18...    One
# 18  Book Customer                       Libertarianism for Beginners    Two
# 19  Book Customer                            It's Only the Himalayas    Two
#
#               Comment Tag    Price
# 0   Book Review Available  Â£51.77
# 1   Book Review Available  Â£53.74
# 2   Book Review Available  Â£50.10
# 3   Book Review Available  Â£47.82
# 4   Book Review Available  Â£54.23
# 5   Book Review Available  Â£22.65
# 6   Book Review Available  Â£33.34
# 7   Book Review Available  Â£17.93
# 8   Book Review Available  Â£22.60
# 9   Book Review Available  Â£52.15
# 10  Book Review Available  Â£13.99
# 11  Book Review Available  Â£20.66
# 12  Book Review Available  Â£17.46
# 13  Book Review Available  Â£52.29
# 14  Book Review Available  Â£35.02
# 15  Book Review Available  Â£57.25
# 16  Book Review Available  Â£23.88
# 17  Book Review Available  Â£37.59
# 18  Book Review Available  Â£51.33
# 19  Book Review Available  Â£45.17
# Data saved to book_reviews.csv
